# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as pld
import seaborn as sns
import sqlite3

# %% [markdown]
# # Exercise 1
#
# Using the same Data Base as in lecture 2, please execute the following:
#
# **1.1** Select unique values in the year column and order them in acsending order. How many unique values are there?
#
# **1.2** Create a column with vehicle age values
#
# **1.3** If a vehicle is older than 45 years, then label it as "45+". Otherwise, label it as "<45". Create a new column that takes these two values
#
# **1.4** How many vehicles are in our dataset that are under 45 and 45 and over?
#
# **1.5** List all unique vehicle name values that have 8 cylinders with horsepower that is greater than 125 but doesn't exceed 200

# %%
# 1

conn = sqlite3.connect('../data/mtcars.sqlite')
df = pd.read_sql_query("SELECT * FROM results", conn)
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0      130.0  3504.0          12.0    70
# 1    15.0          8         350.0      165.0  3693.0          11.5    70
# 2    18.0          8         318.0      150.0  3436.0          11.0    70
# 3    16.0          8         304.0      150.0  3433.0          12.0    70
# 4    17.0          8         302.0      140.0  3449.0          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0       86.0  2790.0          15.6    82
# 393  44.0          4          97.0       52.0  2130.0          24.6    82
# 394  32.0          4         135.0       84.0  2295.0          11.6    82
# 395  28.0          4         120.0       79.0  2625.0          18.6    82
# 396  31.0          4         119.0       82.0  2720.0          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
pd.read_sql_query("""SELECT DISTINCT year 
                  FROM results order by year ASC
                  """, conn)
# Out:
#     year
# 0     70
# 1     71
# 2     72
# 3     73
# 4     74
# 5     75
# 6     76
# 7     77
# 8     78
# 9     79
# 10    80
# 11    81
# 12    82

# %%
c = conn.cursor()
cursor = c.execute("""
ALTER TABLE results
ADD age INT NOT NULL DEFAULT(0)
""")

# %%
df = pd.read_sql_query("SELECT * FROM results", conn)
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0      130.0  3504.0          12.0    70
# 1    15.0          8         350.0      165.0  3693.0          11.5    70
# 2    18.0          8         318.0      150.0  3436.0          11.0    70
# 3    16.0          8         304.0      150.0  3433.0          12.0    70
# 4    17.0          8         302.0      140.0  3449.0          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0       86.0  2790.0          15.6    82
# 393  44.0          4          97.0       52.0  2130.0          24.6    82
# 394  32.0          4         135.0       84.0  2295.0          11.6    82
# 395  28.0          4         120.0       79.0  2625.0          18.6    82
# 396  31.0          4         119.0       82.0  2720.0          19.4    82
#
#      origin                       name  age
# ...

# %%
c = conn.cursor()
cursor = c.execute(""" 
UPDATE results
SET age=123-year
""")

# %%
df = pd.read_sql_query("SELECT * FROM results", conn)
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0      130.0  3504.0          12.0    70
# 1    15.0          8         350.0      165.0  3693.0          11.5    70
# 2    18.0          8         318.0      150.0  3436.0          11.0    70
# 3    16.0          8         304.0      150.0  3433.0          12.0    70
# 4    17.0          8         302.0      140.0  3449.0          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0       86.0  2790.0          15.6    82
# 393  44.0          4          97.0       52.0  2130.0          24.6    82
# 394  32.0          4         135.0       84.0  2295.0          11.6    82
# 395  28.0          4         120.0       79.0  2625.0          18.6    82
# 396  31.0          4         119.0       82.0  2720.0          19.4    82
#
#      origin                       name  age
# ...

# %%
df = pd.read_sql_query("""
SELECT *,
CASE WHEN age>45 THEN '45+' ELSE '<45' END AS classif
FROM results""",conn)

# %%
df.to_sql(
    name="results",
    con=conn, 
    schema=None, 
    if_exists='replace', 
    index=False, 
)
# Out:
# 397

# %%
df = pd.read_sql_query("SELECT * FROM results", conn)
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0      130.0  3504.0          12.0    70
# 1    15.0          8         350.0      165.0  3693.0          11.5    70
# 2    18.0          8         318.0      150.0  3436.0          11.0    70
# 3    16.0          8         304.0      150.0  3433.0          12.0    70
# 4    17.0          8         302.0      140.0  3449.0          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0       86.0  2790.0          15.6    82
# 393  44.0          4          97.0       52.0  2130.0          24.6    82
# 394  32.0          4         135.0       84.0  2295.0          11.6    82
# 395  28.0          4         120.0       79.0  2625.0          18.6    82
# 396  31.0          4         119.0       82.0  2720.0          19.4    82
#
#      origin                       name  age classif
# ...

# %%
df = pd.read_sql_query("""SELECT COUNT(name) AS Num_vehicules, classif FROM results GROUP BY classif""",conn)
df
# Out:
#    Num_vehicules classif
# 0            244     45+
# 1            153     <45

# %%
df = pd.read_sql_query("""SELECT * FROM results""",conn)
youngest_classif = df['age'].min()
oldest_classif= df['age'].max()
print('Most recent car:', youngest_classif, ' |  Oldest car:',oldest_classif)
# Out:
# Most recent car: 41  |  Oldest car: 53

# %%
# 1.4 
# There are 397 vehicules total 
# 244 vehicules are classified as 45+
# 153 vehicules are more recent cars and classified <45

# NOTE: the most recent car is 41 years old
# NOTE: the oldest car is 53 years old

# %% [markdown]
# #### 1.5 List all unique vehicle name values that have 8 cylinders with horsepower that is greater than 125 but doesn't exceed 200

# %%
df = pd.read_sql_query("""SELECT DISTINCT * FROM results WHERE cylinders=8 AND horsepower > 125 AND horsepower<=200""",conn)
df
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0   18.0          8         307.0      130.0  3504.0          12.0    70
# 1   15.0          8         350.0      165.0  3693.0          11.5    70
# 2   18.0          8         318.0      150.0  3436.0          11.0    70
# 3   16.0          8         304.0      150.0  3433.0          12.0    70
# 4   17.0          8         302.0      140.0  3449.0          10.5    70
# ..   ...        ...           ...        ...     ...           ...   ...
# 81  16.9          8         350.0      155.0  4360.0          14.9    79
# 82  15.5          8         351.0      142.0  4054.0          14.3    79
# 83  19.2          8         267.0      125.0  3605.0          15.0    79
# 84  18.5          8         360.0      150.0  3940.0          13.0    79
# 85  23.0          8         350.0      125.0  3900.0          17.4    79
#
#     origin                                  name  age classif
# ...

# %% [markdown]
# # Exercise 2 Songs Database
#
# **2.1** Take the songs dataset and turn it into a single `sqlite` database.

# %%
# 2.1
df_song = pd.read_csv('../data/song_data.csv')
df_song
# Out:
#                         song_name  song_popularity  song_duration_ms  \
# 0      Boulevard of Broken Dreams               73            262333
# 1                      In The End               66            216933
# 2               Seven Nation Army               76            231733
# 3                      By The Way               74            216933
# 4               How You Remind Me               56            223826
# ...                           ...              ...               ...
# 18830              Let It Breathe               60            159645
# 18831                     Answers               60            205666
# 18832      Sudden Love (Acoustic)               23            182211
# 18833           Gentle on My Mind               55            352280
# 18834                    Up to Me               60            193533
#
#        acousticness  danceability  energy  instrumentalness  key  liveness  \
# ...

# %%
conn1 = sqlite3.connect('df_song.sqlite')
df_song.to_sql('songs',con=conn1,index=False,if_exists='replace')
# Out:
# 18835

# %%
pd.read_sql_query("""SELECT name FROM sqlite_master WHERE type='table' """,conn1)
# Out:
#     name
# 0  songs

# %%
df_sg = pd.read_sql_query("""SELECT * FROM songs """,conn1)
df_sg
# Out:
#                         song_name  song_popularity  song_duration_ms  \
# 0      Boulevard of Broken Dreams               73            262333
# 1                      In The End               66            216933
# 2               Seven Nation Army               76            231733
# 3                      By The Way               74            216933
# 4               How You Remind Me               56            223826
# ...                           ...              ...               ...
# 18830              Let It Breathe               60            159645
# 18831                     Answers               60            205666
# 18832      Sudden Love (Acoustic)               23            182211
# 18833           Gentle on My Mind               55            352280
# 18834                    Up to Me               60            193533
#
#        acousticness  danceability  energy  instrumentalness  key  liveness  \
# ...

# %% [markdown]
# # 2.2 Queries
#
# **2.2.1** Use a single query to see if your favorite song is in this dataset
#
# **2.2.2** How many unique popularity scores are there?
#
# **2.2.3** How many song names are in this dataset that contain _'radio edit'_ in their name? Make sure your query is not case sensitive and there is only one single character (space) between _'radio'_ and _'edit'_.
#
# **2.2.4** Write an SQL query to report songs with popularity of 99 and above. How many songs are there?
#
# **2.2.5** Create a new column that contains song duration in the following format m:s. Example, the duration of Boulevard of Broken Dreams is 4:22
#
# **2.2.6** Display the minimum, maximum and average popularity scores. The output of your query should contain only one row with 3 columns.
#
# **2.2.7** Display average popularity scores and count for songs that contain "love" in their name and those that don't. Is there any difference in their popularity?
#
# **2.2.8** Display top 5 songs with the longest names.

# %%
# 2.2.1 Use a single query to see if your favorite song is in this dataset
pd.read_sql_query("""SELECT * FROM songs WHERE song_name LIKE '%sunshine of%'""",conn1)
# Out:
#                song_name  song_popularity  song_duration_ms  acousticness  \
# 0  Sunshine Of Your Love               72            250000         0.475
# 1  Sunshine Of Your Love               72            250000         0.475
# 2  Sunshine Of Your Love               32            250000         0.475
#
#    danceability  energy  instrumentalness  key  liveness  loudness  \
# 0         0.684   0.481          0.000066    2     0.118    -12.59
# 1         0.684   0.481          0.000066    2     0.118    -12.59
# 2         0.684   0.481          0.000066    2     0.118    -12.59
#
#    audio_mode  speechiness    tempo  time_signature  audio_valence
# 0           1       0.0384  115.078               4          0.784
# 1           1       0.0384  115.078               4          0.784
# 2           1       0.0384  115.078               4          0.784

# %%
# 2.2.2 How many unique popularity scores are there?

# There are as many unique scores as there are unique songs : 14894

pd.read_sql_query("""SELECT DISTINCT song_name, song_popularity FROM songs""", conn1)
# Out:
#                         song_name  song_popularity
# 0      Boulevard of Broken Dreams               73
# 1                      In The End               66
# 2               Seven Nation Army               76
# 3                      By The Way               74
# 4               How You Remind Me               56
# ...                           ...              ...
# 14889              Let It Breathe               60
# 14890                     Answers               60
# 14891      Sudden Love (Acoustic)               23
# 14892           Gentle on My Mind               55
# 14893                    Up to Me               60
#
# [14894 rows x 2 columns]

# %%
# 2.2.3 How many song names are in this dataset that contain 'radio edit' in their name? 
# Make sure your query is not case sensitive and there is only one single character (space)
# between 'radio' and 'edit'.

# %%
pd.read_sql_query("""SELECT * FROM songs WHERE LOWER(song_name) LIKE '%radio edit%'""",conn1)
# Out:
#                                              song_name  song_popularity  \
# 0    Get Lucky (feat. Pharrell Williams & Nile Rodg...               77
# 1                                  I Wish - Radio Edit               63
# 2                                Lovefool - Radio Edit               75
# 3                                Lovefool - Radio Edit               75
# 4      Are You Ready For Love - '79 Version Radio Edit               60
# ..                                                 ...              ...
# 127                        Nothing Change - Radio Edit               54
# 128                           Don't Worry - Radio Edit               59
# 129                              Love Gun - Radio Edit                3
# 130                                   NRG - Radio Edit               43
# 131  Get Lucky (feat. Pharrell Williams & Nile Rodg...               77
#
#      song_duration_ms  acousticness  danceability  energy  instrumentalness  \
# ...

# %%
# 2.2.4 Write an SQL query to report songs with popularity of 99 and above. How many songs are there?

# %%
pd.read_sql_query("""SELECT COUNT(*) FROM songs WHERE song_popularity >99""",conn1)
# Out:
#    COUNT(*)
# 0        12

# %%
# 2.2.5 Create a new column that contains song duration in the following format m:s.
# Example, the duration of Boulevard of Broken Dreams is 4:22

c = conn1.cursor()
cursor = c.execute(f"ALTER TABLE songs ADD duration varchar(10)")

# %%
# Out:
#                         song_name  song_popularity  song_duration_ms  \
# 0      Boulevard of Broken Dreams               73            262333
# 1                      In The End               66            216933
# 2               Seven Nation Army               76            231733
# 3                      By The Way               74            216933
# 4               How You Remind Me               56            223826
# ...                           ...              ...               ...
# 18830              Let It Breathe               60            159645
# 18831                     Answers               60            205666
# 18832      Sudden Love (Acoustic)               23            182211
# 18833           Gentle on My Mind               55            352280
# 18834                    Up to Me               60            193533
#
#        acousticness  danceability  energy  instrumentalness  key  liveness  \
# ...

# %%
cursor = c.execute(f"UPDATE songs SET duration= CAST((song_duration_ms/1000/60) AS varchar) || ':' || CAST((song_duration_ms/1000%60) AS varchar) ")

# %%
pd.read_sql_query("""SELECT * FROM songs""",conn1)
# Out:
#                         song_name  song_popularity  song_duration_ms  \
# 0      Boulevard of Broken Dreams               73            262333
# 1                      In The End               66            216933
# 2               Seven Nation Army               76            231733
# 3                      By The Way               74            216933
# 4               How You Remind Me               56            223826
# ...                           ...              ...               ...
# 18830              Let It Breathe               60            159645
# 18831                     Answers               60            205666
# 18832      Sudden Love (Acoustic)               23            182211
# 18833           Gentle on My Mind               55            352280
# 18834                    Up to Me               60            193533
#
#        acousticness  danceability  energy  instrumentalness  key  liveness  \
# ...

# %%
# 2.2.6 Display the minimum, maximum and average popularity scores. 
# The output of your query should contain only one row with 3 columns.
pd.read_sql_query("""SELECT MIN(song_popularity) as minimum, MAX(song_popularity) as maximum, AVG(song_popularity) as average FROM songs WHERE song_popularity = 
                        (SELECT MIN(song_popularity) FROM songs) 
                        OR 
                        (SELECT MAX(song_popularity) FROM songs)
                        OR 
                        (SELECT AVG(song_popularity) FROM songs  )
                        """,conn1)
# Out:
#    minimum  maximum    average
# 0        0      100  52.991877

# %%
# 2.2.7 Display average popularity scores and count for songs that contain "love" in their name
# and those that don't. Is there any difference in their popularity?
pd.read_sql_query('''SELECT AVG(song_popularity) as popularity_with_love, COUNT(song_name) as numbers_of_songs FROM songs WHERE song_name LIKE '%love%' ''', conn1)
# Out:
#    popularity_with_love  numbers_of_songs
# 0             54.390411               730

# %%
pd.read_sql_query('''SELECT AVG(song_popularity) as popularity_no_love, COUNT(song_name) FROM songs WHERE song_name NOT LIKE '%love%' ''',conn1)
# Out:
#    popularity_no_love  COUNT(song_name)
# 0           52.935487             18105

# %%
# There are less songs with 'LOVE' in their title, but they are more popular on average

# %%
# 2.2.8 Display top 5 songs with the longest names.

# %%
pd.read_sql_query('''SELECT * FROM songs ORDER BY LENGTH(song_name) DESC LIMIT 5''', conn1)
# Out:
#                                            song_name  song_popularity  \
# 0  Viajo Sin Ver (Remix) [feat. De La Ghetto, Alm...               66
# 1  Riff Off: Mickey/Like A Virgin/Hit Me With You...               58
# 2  Wu Tang Forever (ft. Ghostface Killah, Raekwon...               79
# 3  Bellas Finals: Price Tag/Don’t You (Forget Abo...               60
# 4  I Don’t Wanna Live Forever (Fifty Shades Darke...               44
#
#    song_duration_ms  acousticness  danceability  energy  instrumentalness  \
# 0            569260        0.5560         0.805   0.823          0.000000
# 1            223840        0.5760         0.577   0.499          0.000000
# 2            487960        0.1460         0.703   0.807          0.000000
# 3            217080        0.5690         0.477   0.691          0.000000
# 4            245200        0.0631         0.735   0.451          0.000013
#
#    key  liveness  loudness  audio_mode  speechiness    tempo  time_signature  \
# ...
